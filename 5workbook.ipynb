# %% [markdown]
# Румянцева Елизавета Ивановна КВБО-01-21

# %% [markdown]
# # 1 Задание
# Создайте класс по работе с тригонометрическими функциями. В классе должны быть реализованы функции вычисления:

# %% [markdown]
# -косинуса

# %% [markdown]
# -синуса

# %% [markdown]
# -тангенса

# %% [markdown]
# -арктангенса

# %% [markdown]
# -арккосинуса

# %% [markdown]
# -арксинуса

# %% [markdown]
# -перевода из градусов в радианы

# %%
import sympy as sym
from sympy import *
import numpy as np
import math
import pandas as pd
def factorial(value):
    factorial=1
    result=value
    while(result>1):
        factorial=factorial*result
        result=result-1
    return factorial
pi=3.14159265359;
class gradus():
    value=0.1
    def returnValue(self):
        return self.value
    def __init__(self,znachenie):
        self.value=znachenie
    def sinus(self):
        result=0
        flag=1
        if(self.value<0):
            flag=0
            self.value=self.value*(-1)
        while(self.value>360):
            self.value=self.value-360
        if((self.value>=0)and(self.value<=90)):
            degree= Toradians(self.value)
            result= round((degree - (degree**3/factorial(3)) + (degree**5/factorial(5)) - 
                          (degree**7/factorial(7))),2)
        if((self.value>90)and(self.value<180)):
            degree= Toradians(self.value-90)
            result= round((degree - (degree**3/factorial(3)) + (degree**5/factorial(5)) - 
                          (degree**7/factorial(7))),2)
        if((self.value>=180)and(self.value<=270)):
            degree= Toradians(self.value-180)
            result= round(-(degree - (degree**3/factorial(3)) + (degree**5/factorial(5)) - 
                          (degree**7/factorial(7))),2)
        if((self.value>270)and(self.value<=360)):
            degree= Toradians(self.value-270)
            result= round(-(degree - (degree**3/factorial(3)) + (degree**5/factorial(5)) - 
                          (degree**7/factorial(7))),2)
        if(flag==1):
            return result
        else:
            return result*(-1)
    def cosinus(self):
        result= round(sqrt(1-(self.sinus())**2),2)
        return result
    def tangens(self):
        if(self.cosinus()!=0):
            result= round((self.sinus()/self.cosinus()),2)
            return result
        else:
            return "Не существует"
def arctangens(value):
    if((value>-90)and(value<90)):
        result= round(value-value**3/3+value**5/5-value**7/7+value**9/9-value**11/11+value**13/13-
                      value**15/15+value**17/17-value**19/19,2)
        return result
    else:
        return "Не существует"
def Toradians(value):
    return (value*pi)/180;
def arccotangens(value):
    return pi/2-arctangens(value)
def arcsinus(value):
    if((value<=1)and(value>=-1)):
        if(value==1):
            return pi/4
        if(value==-1):
            return -pi/4
        else:
            return arctangens(value/math.sqrt(1-value**2))
    else:
        return "Не существует"
def arccosinus(value):
    if ((value>=-1)and(value<=1)):
        if(value==-1):
            return pi
        if(value==1):
            return 0
        else:
            return pi/2-arcsinus(value)
    else:
        return "Не сущесвует"
znachenie=[gradus(0),gradus(30),gradus(45),gradus(60),gradus(90),gradus(180),gradus(270)]
tablica1=[["x","0","30","45","60","90","180","270"],
          ["sin(x)",znachenie[0].sinus(),znachenie[1].sinus(),znachenie[2].sinus(),
                znachenie[3].sinus(),znachenie[4].sinus(),znachenie[5].sinus(),
                znachenie[6].sinus()],
          ["cos(x)",znachenie[0].cosinus(),znachenie[1].cosinus(),znachenie[2].cosinus(),
                znachenie[3].cosinus(),znachenie[4].cosinus(),znachenie[5].cosinus(),
                znachenie[6].cosinus()],
          ["tg(x)",znachenie[0].tangens(),znachenie[1].tangens(),znachenie[2].tangens(),
                znachenie[3].tangens(),znachenie[4].tangens(),znachenie[5].tangens(),
                znachenie[6].tangens()]]
znachenieInt=["x",-4.5,-4,-3.5,-3,-2.5,-2,-1.5,-1,-0.5,0,0.5,1,1.5,2,2.5,3,3.5,4,4.5]
tablica2=[znachenieInt,
          ["arctg()",arctangens(znachenieInt[1]),arctangens(znachenieInt[2]),
           arctangens(znachenieInt[3]),arctangens(znachenieInt[4]),arctangens(znachenieInt[5]),
           arctangens(znachenieInt[6]),arctangens(znachenieInt[7]),arctangens(znachenieInt[8]),
           arctangens(znachenieInt[9]),arctangens(znachenieInt[10]),arctangens(znachenieInt[11]),
           arctangens(znachenieInt[12]),arctangens(znachenieInt[13]),arctangens(znachenieInt[14]),
           arctangens(znachenieInt[15]),arctangens(znachenieInt[16]),arctangens(znachenieInt[17]),
           arctangens(znachenieInt[18])],
          ["arсcos()",arccosinus(znachenieInt[1]),arccosinus(znachenieInt[2]),
           arccosinus(znachenieInt[3]),arccosinus(znachenieInt[4]),arccosinus(znachenieInt[5]),
           arccosinus(znachenieInt[6]),arccosinus(znachenieInt[7]),arccosinus(znachenieInt[8]),
           arccosinus(znachenieInt[9]),arccosinus(znachenieInt[10]),arccosinus(znachenieInt[11]),
           arccosinus(znachenieInt[12]),arccosinus(znachenieInt[13]),arccosinus(znachenieInt[14]),
           arccosinus(znachenieInt[15]),arccosinus(znachenieInt[16]),arccosinus(znachenieInt[17]),
           arccosinus(znachenieInt[18])],
          ["arcsin()",arcsinus(znachenieInt[1]),arccosinus(znachenieInt[2]),
           arcsinus(znachenieInt[3]),arcsinus(znachenieInt[4]),arcsinus(znachenieInt[5]),
           arcsinus(znachenieInt[6]),arcsinus(znachenieInt[7]),arcsinus(znachenieInt[8]),
           arcsinus(znachenieInt[9]),arcsinus(znachenieInt[10]),arcsinus(znachenieInt[11]),
           arcsinus(znachenieInt[12]),arcsinus(znachenieInt[13]),arcsinus(znachenieInt[14]),
           arcsinus(znachenieInt[15]),arcsinus(znachenieInt[16]),arcsinus(znachenieInt[17]),
           arcsinus(znachenieInt[18])]]
valueOfDegree=[" ",0,30,45,60,90,120,135,150,180,210,225,240,270,300,315,330,360]
tablica3=[valueOfDegree,
          ["degree to radiant",Toradians(valueOfDegree[0+1]),Toradians(valueOfDegree[1+1]),
                 Toradians(valueOfDegree[2+1]),Toradians(valueOfDegree[3+1]),
                 Toradians(valueOfDegree[4+1]),Toradians(valueOfDegree[5+1]),
                 Toradians(valueOfDegree[6+1]),Toradians(valueOfDegree[7+1]),
                 Toradians(valueOfDegree[8+1]),Toradians(valueOfDegree[9+1]),
                 Toradians(valueOfDegree[10+1]),Toradians(valueOfDegree[11+1]),
                 Toradians(valueOfDegree[12+1]),Toradians(valueOfDegree[13+1]),
                 Toradians(valueOfDegree[14+1]),Toradians(valueOfDegree[15+1]),
                 Toradians(valueOfDegree[16+1])]]
pd.DataFrame(tablica1)
# Out:
#         0                 1     2     3     4              5  \
# 0       x                 0    30    45    60             90
# 1  sin(x)               0.0   0.5  0.71  0.87            1.0
# 2  cos(x)  1.00000000000000  0.87  0.70  0.49            0.0
# 3   tg(x)                 0  0.57  1.01  1.77  Не существует
#
#                   6              7
# 0               180            270
# 1              -0.0           -1.0
# 2  1.00000000000000            0.0
# 3                 0  Не существует

# %% [markdown]
# Вычисление тригонометрических функций возможно и без библиотеки math.
# Вычисления были произведены с помощью рядов Тейлора и основных тригонометрических свойств

# %%
pd.DataFrame(tablica2)
# Out:
#          0                    1                   2              3   \
# 0         x                 -4.5                  -4           -3.5
# 1   arctg()  128519455605.300003  13523452614.290001  1048725495.93
# 2  arсcos()         Не сущесвует        Не сущесвует   Не сущесвует
# 3  arcsin()        Не существует        Не сущесвует  Не существует
#
#               4              5              6              7         8   \
# 0             -3           -2.5             -2           -1.5 -1.000000
# 1    54423316.65     1624767.38       21580.21          77.08 -0.760000
# 2   Не сущесвует   Не сущесвует   Не сущесвует   Не сущесвует  3.141593
# 3  Не существует  Не существует  Не существует  Не существует -0.785398
#
#          9         10        11        12             13             14  \
# 0 -0.500000  0.000000  0.500000  1.000000            1.5              2
# 1 -0.460000  0.000000  0.460000  0.760000         -77.08      -21580.21
# ...

# %%
pd.DataFrame(tablica3)
# Out:
#                   0    1          2          3          4          5   \
# 0                     0.0  30.000000  45.000000  60.000000  90.000000
# 1  degree to radiant  0.0   0.523599   0.785398   1.047198   1.570796
#
#            6           7           8           9           10          11  \
# 0  120.000000  135.000000  150.000000  180.000000  210.000000  225.000000
# 1    2.094395    2.356194    2.617994    3.141593    3.665191    3.926991
#
#           12          13          14          15          16          17
# 0  240.00000  270.000000  300.000000  315.000000  330.000000  360.000000
# 1    4.18879    4.712389    5.235988    5.497787    5.759587    6.283185

# %% [markdown]
# # 2 Задание
# Представьте дерево показанное на рисунке с использованием списка из списков. Выведете на печать корень дерева, а также его левое и правое поддеревья

# %%
T=["a",["b",["d","e"]],["c",["f"]]]
print("Корень дерева")
print(T[0])
print("Левое поддеревье")
print("  ",T[1][0])
print(T[1][1][0],"  ",T[1][1][1])
print("Правое поддеревье")
print("  ",T[2][0])
print("  ",T[2][1][0])
# Out:
# Корень дерева
# a
# Левое поддеревье
#    b
# d    e
# Правое поддеревье
#    c
#    f

# %% [markdown]
# # Задание 3
# ###### Дан класс, описывающий бинарное дерево.
# ###### class Tree:
# ###### def __init__(self, data):
# ###### self.left = None
# ###### self.right = None
# ###### self.data = data
# ###### Реализуйте функцию для вставки нового элемента в дерево по следующим правилам:
# ###### • Левое поддерево узла содержит только узлы со значениями меньше, чем значение в узле.
# ###### • Правое поддерево узла содержит только узлы со значениями меньше,чем значение в узле.
# ###### • Каждое из левого и правого поддеревьев также должно быть бинарным деревом поиска.
# ###### • Не должно быть повторяющихся узлов.
# ###### Метод вставки сравнивает значение узла с родительским узлом и решает куда доваить элемент (в левое или правое поддерево). Перепишите, метод PrintTree для печати полной версии дерева.

# %%
import itertools
import networkx as nx
import numpy.random as rnd
import matplotlib.pyplot as plt
class Tree:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data
    def returnData(self):
        return self.data
    def equals(self,node):
        if(self.data==node.data):
            return true
        if(self.data!=node.data):
            return false
    def insert(self, data,tree):
        indicator=0
        for i in range(0,len(tree)):
            if(tree[i].data==data):
                indicator=1
        if(indicator==0):
            flag=0
            if self.data:
                if data < self.data:
                    if self.left is None:
                        self.left = Tree(data)
                        flag=1
                        tree.append(self.left)
                    if((flag==0)and(self.right is None)):
                        self.right=Tree(data)
                        flag=1
                        tree.append(self.right)
                    else:
                        self.left.insert(data,tree)
    
    def add_edge(self,tree):
        graph = nx.Graph()
        for i in range(0,len(tree)):
            if(tree[i].left!=None):
                graph.add_edge(tree[i].data, tree[i].left.returnData())
            if(tree[i].right!=None):
                graph.add_edge(tree[i].data, tree[i].right.returnData())
        nx.draw_kamada_kawai(graph,node_color='blue',node_size=1000,with_labels=True)
def raspredelenie(root,level,massiv):
    if root:
        level=level+1
        massiv.append([level,root])
        raspredelenie(root.left,level,massiv)
        raspredelenie(root.right,level,massiv)   
def height(node):
    if node is None:
        return 0
    else:
        return max(height(node.left), height(node.right)) + 1
tree=list()
root = Tree(1453)
tree.append(root)
root.insert(234,tree)
root.insert(233,tree)
root.right.insert(230,tree)
root.right.insert(220,tree)
root.left.insert(210,tree)
root.right.insert(200,tree)
root.insert(100,tree)
root.insert(100,tree)
root.insert(100,tree)
root.insert(80,tree)
root.insert(1,tree)
root.insert(1,tree)
root.insert(45,tree)
root.add_edge(tree)
tree=list()
root1 = Tree(1453)
tree.append(root)
root1.insert(234,tree)
root1.insert(233,tree)
root1.right.insert(230,tree)
root1.right.insert(220,tree)
root1.left.insert(210,tree)
root1.right.insert(200,tree)
root1.insert(100,tree)
root1.insert(100,tree)
root1.insert(100,tree)
root1.insert(80,tree)
root1.insert(1,tree)
root1.insert(1,tree)
root1.insert(45,tree)
root1.insert(30,tree)

# %%
root1.add_edge(tree)

# %% [markdown]
# # Задание 4
# Постройте классификатор на основе дерева принятия решений следующего датасета: X=np.array([[-1,-1],[-2,-1],[-3,-2],[1,1],[2,1],[3,2]])

# %% [markdown]
# target=[0,0,0,1,1,1]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
X=np.array([[-1,-1],[-2,-1],[-3,-2],[1,1],[2,1],[3,2]])
target=[0,0,0,1,1,1]
X_train,X_test,y_train,y_test=train_test_split(X,target,test_size=0.2)
print("X_train: \n",X_train)
print("X_test: \n",X_test)
print("y_train: \n",y_train)
print("y_test: \n",y_test)
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier()
classifier.fit(X_train,y_train)
from sklearn import tree
tree.plot_tree(classifier)
y_pred=classifier.predict(X_test)
print("y_pred: \n",y_pred,"\n")
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# X_train:
#  [[ 2  1]
#  [-2 -1]
#  [ 3  2]
#  [-3 -2]]
# X_test:
#  [[ 1  1]
#  [-1 -1]]
# y_train:
#  [1, 0, 1, 0]
# y_test:
#  [1, 0]
# y_pred:
#  [1 0]
#
# [[1 0]
#  [0 1]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2

# %% [markdown]
# # Задание 5
# Постройте модель регрессии для данных из предыдущей рабочей тетради.Для примера можно взять потребления газа (в миллионах галлонов) в 48 штатах США или набор данных о качестве красного вина:
# https://raw.githubusercontent.com/likarajo/petrol_consumption/master/data/petrol_consumption.csv
# https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/master/winequality-red.csv

# %% [markdown]
# Постройте прогноз. Оцените точность модели.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
url="https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/master/winequality-red.csv"
dataset=pd.read_csv(url)
dataset.head()
print(dataset.shape)
dataset.describe()
plt.scatter(dataset['alcohol'],dataset['quality'],color='purple',alpha=0.3,label="Зависимость качества вина от количества алкоголя")
plt.xlabel("Количество алкоголя")
plt.ylabel("Качество вина")
plt.show()
from sklearn.tree import DecisionTreeRegressor
X=dataset.iloc[:,:-1].values
y=dataset.iloc[:,1].values
print(X)
print(y)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=0)
regressor=DecisionTreeRegressor(max_depth= 3)
regressor.fit(X_train,y_train)
from sklearn import tree
y_pred=regressor.predict(X_test)
df=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
print(df.head())
print(df.tail())
from sklearn import metrics
print('Средняквадратичная ошибка',metrics.mean_squared_error(y_test,y_pred))
print('Абсолютная ошибка',metrics.mean_absolute_error(y_test,y_pred))
from sklearn.metrics import classification_report,confusion_matrix
cutoff = 0.7                              # decide on a cutoff limit
y_pred_classes = np.zeros_like(y_pred)    # initialise a matrix full with zeros
y_pred_classes[y_pred > cutoff] = 1
y_test_classes = np.zeros_like(y_pred)
y_test_classes[y_test > cutoff] = 1
print(confusion_matrix(y_test_classes, y_pred_classes))
from matplotlib.transforms import Affine2D
import mpl_toolkits.axisartist.floating_axes as floating_axes
fig = plt.figure()
ax = fig.add_subplot(111)
fig = plt.gcf()
fig.set_size_inches(20, 20) #dimensions you want
tree.plot_tree(regressor)
plt.show()
# Out:
# (1599, 12)
# [[ 7.4    0.7    0.    ...  3.51   0.56   9.4  ]
#  [ 7.8    0.88   0.    ...  3.2    0.68   9.8  ]
#  [ 7.8    0.76   0.04  ...  3.26   0.65   9.8  ]
#  ...
#  [ 6.3    0.51   0.13  ...  3.42   0.75  11.   ]
#  [ 5.9    0.645  0.12  ...  3.57   0.71  10.2  ]
#  [ 6.     0.31   0.47  ...  3.39   0.66  11.   ]]
# [0.7   0.88  0.76  ... 0.51  0.645 0.31 ]
#    Actual  Predicted
# 0   0.470   0.495566
# 1   0.820   0.831286
# 2   0.290   0.246404
# 3   0.645   0.685714
# 4   0.450   0.417561
#      Actual  Predicted
# 155   0.685   0.685714
# 156   0.580   0.587160
# 157   0.645   0.685714
# 158   0.500   0.495566
# 159   0.400   0.417561
# Средняквадратичная ошибка 0.0008973972113443873
# Абсолютная ошибка 0.024316597897607248
# [[143   0]
#  [  7  10]]
